# %% [raw]
# The Isuue:  The @dataclasses in python 3.7 makes the defenition of classes (with static fields) rather easier and cleaner. The issue is when you try to inherit from a regularly defined class (or another dataclass), it may raise certain complaints. The rule is that you cannot inherit from a class that has an attribute that has a defaul value (i.e. it will be considered as non-positional).
# https://stackoverflow.com/questions/51575931/class-inheritance-in-python-3-7-dataclasses
#
# (SideNote: The defenition of default values for the @dataclasses may have its own issues as well. for example  the statement  atrib: List [SomeClass] = []  is not allowed and you will need to use some tool from the package  "field"  with default_factory  --> https://www.python.org/dev/peps/pep-0557/#default-factory-functions)
#
# Now why even would we want to do such a thing?
# so for the GQL queires we make on the DBs, we get big JSON schemas that can be easily(?) converted to nicely formed quicktype classes defined in this way. We may want to add some functionality without extensively change the original classes. So in one such applications the parent classes defined unaware of this rules throws you all kinds of odd erorrs.
# So let us work with this example.

# %%
from __future__ import annotations
from dataclasses import dataclass
from typing import List, Any, TypeVar, Callable, Type, cast
from abc import ABC, abstractmethod



Optopy_inputs={
    "settings": {
      "horizon_length": 24.0,
      "interval_length": 0.25,
     
    },
}

# %%
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings:
    horizon_length: float
    interval_length: float
      

    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)



@dataclass
class OptopyInput:
    settings: Settings
    

    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)

# %%
data=optopy_input_from_dict(Optopy_inputs)

data.settings.horizon_length
# Out:
# 24.0

# %% [raw]
# Now adding this parent classes to add a bit of flexibility

# %%
class Component(ABC):

    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass
    
class Composite(Component):

    def __init__(self) -> None:
        self._children: List[Component] = []


    def add(self, component: Component) -> None:
        self._children.append(component)
        component.parent = self

        
composite_obj_one= Composite()
composite_obj_one._children

composite_obj_two=Composite()
composite_obj_two.add(composite_obj_one)
print(composite_obj_one.parent)

print(composite_obj_two._children)
# Out:
# <__main__.Composite object at 0x7f1c4c28e910>
# [<__main__.Composite object at 0x7f1c4c28e8d0>]

# %% [markdown]
# This is some simple parent class I wish to add to the hirarchy. So this add a parent to each componet object and if the component is composite it will add the chidren.
# Now if we don't initilize parent and children as empty list we get error.

# %%
print(composite_obj_one._children)

print(composite_obj_two.parent)
# Out:
# []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6f799a0d4e7e> in <module>
#       1 print(composite_obj_one._children)
#       2
# ----> 3 print(composite_obj_two.parent)
#
# <ipython-input-5-8150e38852df> in parent(self)
#       3     @property
#       4     def parent(self) -> Component:
# ----> 5         return self._parent
#       6
#       7     @parent.setter
#
# AttributeError: 'Composite' object has no attribute '_parent'

# %% [raw]
# So I initilize the Component similar to composite.
# (side note: Also I want to show children similar to parent, i.e. work with children instead of _children, but this synax below certainly does not work!)
# what I want actually is a custome append method for children(?)

# %%
class Component(ABC):
    
    def __init__(self) -> None:
        self._parent: List[Component] = []

    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass
    
class Composite(Component):

    def __init__(self) -> None:
        self._children: List[Component] = []
 
    @property
    def children(self) -> List[Component]:
        return self._children

    @children.setter
    def children(self, child: Component)-> None:
        self._children.append(child)
        child.parent = self


#     def add(self, component: Component) -> None:
#         self._children.append(component)
#         component.parent = self

        
composite_obj_one= Composite()
composite_obj_one.children

composite_obj_two=Composite()
composite_obj_two.children(composite_obj_one)
print(composite_obj_one.parent)

print(composite_obj_two.children)
print(composite_obj_one.children)

print(composite_obj_two.parent)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-8675f730e47d> in <module>
#      39
#      40 composite_obj_two=Composite()
# ---> 41 composite_obj_two.children(composite_obj_one)
#      42 print(composite_obj_one.parent)
#      43
#
# TypeError: 'list' object is not callable

# %% [raw]
# So forget about Side Note. I use the normal add method.

# %%
class Component(ABC):
    
    def __init__(self) -> None:
        self._parent: List[Component] = []

    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass
    
class Composite(Component):

    def __init__(self) -> None:
        self._children: List[Component] = []
 
    @property
    def children(self) -> List[Component]:
        return self._children

 
    def add(self, component: Component) -> None:
        self._children.append(component)
        component.parent = self

        
composite_obj_one= Composite()
composite_obj_one.children

composite_obj_two=Composite()
composite_obj_two.add(composite_obj_one)
print(composite_obj_one.parent)

print(composite_obj_two.children)
print(composite_obj_one.children)

print(composite_obj_two.parent)
# Out:
# <__main__.Composite object at 0x7f1c4c211310>
# [<__main__.Composite object at 0x7f1c4c211950>]
# []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-5f4c61fe797a> in <module>
#      40 print(composite_obj_one.children)
#      41
# ---> 42 print(composite_obj_two.parent)
#
# <ipython-input-23-5f4c61fe797a> in parent(self)
#       6     @property
#       7     def parent(self) -> Component:
# ----> 8         return self._parent
#       9
#      10     @parent.setter
#
# AttributeError: 'Composite' object has no attribute '_parent'

# %% [raw]
# I guess also should have used super()__init__ ! Dahh!

# %%
class Component(ABC):
    
    def __init__(self) -> None:
        self._parent: List[Component] = []

    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass
    
class Composite(Component):

    def __init__(self) -> None:
        self._children: List[Component] = []
        super().__init__()
 
    @property
    def children(self) -> List[Component]:
        return self._children

 
    def add(self, component: Component) -> None:
        self._children.append(component)
        component.parent = self

        
composite_obj_one= Composite()
composite_obj_one.children

composite_obj_two=Composite()
composite_obj_two.add(composite_obj_one)


print(composite_obj_one.parent)

print(composite_obj_two.children)
print(composite_obj_one.children)

print(composite_obj_two.parent)
# Out:
# <__main__.Composite object at 0x7f1c4c1ce210>
# [<__main__.Composite object at 0x7f1c4c218990>]
# []
# []

# %% [raw]
# now want to combine this with the data quick type.

# %%
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

class Settings(Composite):
    horizon_length: float
    interval_length: float
    
    
    
    def __init__(self,horizon_length, interval_length):
        
        self.horizon_length=horizon_length
        self.interval_length=interval_length
        super().__init__()

    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)



class OptopyInput(Composite):
    settings: Settings
        
    def __init__(self,settings):
        
        self.settings=settings
        super().__init__()
    

    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent=optopy_input_from_dict(Optopy_inputs)

data_with_parent.settings.horizon_length
# Out:
# 24.0

# %%
print(data_with_parent.settings.parent)
print(data_with_parent.settings.children)
print(data_with_parent.parent)
print(data_with_parent.children)
# Out:
# []
# []
# []
# []

# %%
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

class Settings(Composite):
    horizon_length: float
    interval_length: float
    
    
    
    def __init__(self,horizon_length, interval_length):
        
        self.horizon_length=horizon_length
        self.interval_length=interval_length
        super().__init__()

    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)



class OptopyInput(Composite):
    settings: Settings
        
    def __init__(self,settings):
        
        self.settings=settings
        super().__init__()
        self.add(settings)
    

    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent=optopy_input_from_dict(Optopy_inputs)

data_with_parent.settings.horizon_length
print(data_with_parent.settings.parent)
print(data_with_parent.settings.children)
print(data_with_parent.parent)
print(data_with_parent.children)
# Out:
# <__main__.OptopyInput object at 0x7f1c4c216d90>
# []
# []
# [<__main__.Settings object at 0x7f1c4c216c90>]

# %% [raw]
# okay so now I have some basic version of the functionality. Now I would try using the @dataclasses

# %%
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(Composite):
    horizon_length: float
    interval_length: float
    
    
    
#     def __init__(self,horizon_length, interval_length):
        
#         self.horizon_length=horizon_length
#         self.interval_length=interval_length
#         super().__init__()

    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(Composite):
    settings: Settings
        
#     def __init__(self,settings):
        
#         self.settings=settings
#         super().__init__()
#         self.add(settings)
    

    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent=optopy_input_from_dict(Optopy_inputs)

data_with_parent.settings.horizon_length
print(data_with_parent.settings.parent)
print(data_with_parent.settings.children)
print(data_with_parent.parent)
print(data_with_parent.children)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-a19a8c6090fa> in <module>
#      50
#      51 data_with_parent.settings.horizon_length
# ---> 52 print(data_with_parent.settings.parent)
#      53 print(data_with_parent.settings.children)
#      54 print(data_with_parent.parent)
#
# <ipython-input-10-dfc94c31bf23> in parent(self)
#       6     @property
#       7     def parent(self) -> Component:
# ----> 8         return self._parent
#       9
#      10     @parent.setter
#
# AttributeError: 'Settings' object has no attribute '_parent'

# %% [raw]
# now I commented out the part that assigns the settiing as child of OptopyInput, but it still should have given me an empty list, no?
# So maybe (likely) we cannot refer to a regular class when using a dataclass (??)
# Even if we comment out all the others, we can't get the children list, so looks like that composite class has not been initilized.

# %%
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(Composite):
    horizon_length: float
    interval_length: float
    

    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(Composite):
    settings: Settings
  

    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent=optopy_input_from_dict(Optopy_inputs)

data_with_parent.settings.horizon_length

# print(data_with_parent.settings.parent)
print(data_with_parent.settings.children)
# print(data_with_parent.parent)
# print(data_with_parent.children)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-25a4056f83cf> in <module>
#      39
#      40 # print(data_with_parent.settings.parent)
# ---> 41 print(data_with_parent.settings.children)
#      42 # print(data_with_parent.parent)
#      43 # print(data_with_parent.children)
#
# <ipython-input-10-dfc94c31bf23> in children(self)
#      23     @property
#      24     def children(self) -> List[Component]:
# ---> 25         return self._children
#      26
#      27
#
# AttributeError: 'Settings' object has no attribute '_children'

# %% [raw]
# Now i try having the parent classes as dataclasses.

# %%
@dataclass
class ComponentDC(ABC):
    
#     def __init__(self) -> None:
#         self._parent: List[Component] = []

    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass

@dataclass
class CompositeDC(ComponentDC):

#     def __init__(self) -> None:
#         self._children: List[Component] = []
#         super().__init__()
 
    @property
    def children(self) -> List[Component]:
        return self._children

 
    def add(self, component: Component) -> None:
        self._children.append(component)
        component.parent = self

        
composite_obj_one= CompositeDC()
composite_obj_one.children

composite_obj_two=CompositeDC()
composite_obj_two.add(composite_obj_one)


print(composite_obj_one.parent)

print(composite_obj_two.children)
print(composite_obj_one.children)

print(composite_obj_two.parent)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-b728bafcf449> in <module>
#      34
#      35 composite_obj_one= CompositeDC()
# ---> 36 composite_obj_one.children
#      37
#      38 composite_obj_two=CompositeDC()
#
# <ipython-input-19-b728bafcf449> in children(self)
#      25     @property
#      26     def children(self) -> List[Component]:
# ---> 27         return self._children
#      28
#      29
#
# AttributeError: 'CompositeDC' object has no attribute '_children'

# %%
@dataclass
class ComponentDC(ABC):
    
    _parent: List[Component] = []
        

    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass

@dataclass
class CompositeDC(ComponentDC):
    _children: List[Component] = []

 
    @property
    def children(self) -> List[Component]:
        return self._children

 
    def add(self, component: Component) -> None:
        self._children.append(component)
        component.parent = self

        
composite_obj_one= CompositeDC()
composite_obj_one.children

composite_obj_two=CompositeDC()
composite_obj_two.add(composite_obj_one)


print(composite_obj_one.parent)

print(composite_obj_two.children)
print(composite_obj_one.children)

print(composite_obj_two.parent)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-ece41a5359a7> in <module>
#       1 @dataclass
# ----> 2 class ComponentDC(ABC):
#       3
#       4     _parent: List[Component] = []
#       5
#
# /usr/lib/python3.7/dataclasses.py in dataclass(_cls, init, repr, eq, order, unsafe_hash, frozen)
#     989
#     990     # We're called as @dataclass without parens.
# --> 991     return wrap(_cls)
#     992
#     993
#
# /usr/lib/python3.7/dataclasses.py in wrap(cls)
#     981
#     982     def wrap(cls):
# --> 983         return _process_class(cls, init, repr, eq, order, unsafe_hash, frozen)
#     984
#     985     # See if we're being called as @dataclass or @dataclass().
#
# /usr/lib/python3.7/dataclasses.py in _process_class(cls, init, repr, eq, order, unsafe_hash, frozen)
#     832     # we can.
#     833     cls_fields = [_get_field(cls, name, type)
# --> 834                   for name, type in cls_annotations.items()]
#     835     for f in cls_fields:
#     836         fields[f.name] = f
#
# /usr/lib/python3.7/dataclasses.py in <listcomp>(.0)
#     832     # we can.
#     833     cls_fields = [_get_field(cls, name, type)
# --> 834                   for name, type in cls_annotations.items()]
#     835     for f in cls_fields:
#     836         fields[f.name] = f
#
# /usr/lib/python3.7/dataclasses.py in _get_field(cls, a_name, a_type)
#     725     # For real fields, disallow mutable defaults for known types.
#     726     if f._field_type is _FIELD and isinstance(f.default, (list, dict, set)):
# --> 727         raise ValueError(f'mutable default {type(f.default)} for field '
#     728                          f'{f.name} is not allowed: use default_factory')
#     729
#
# ValueError: mutable default <class 'list'> for field _parent is not allowed: use default_factory

# %%
from dataclasses import field

@dataclass
class ComponentDC(ABC):
    
    _parent: List[Component] = field(default_factory=list)  ## do not use [] or list()
        

    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass

@dataclass
class CompositeDC(ComponentDC):
    _children: List[Component] = field(default_factory=list) 

 
    @property
    def children(self) -> List[Component]:
        return self._children

 
    def add(self, component: Component) -> None:
        self._children.append(component)
        component.parent = self

        
composite_obj_one= CompositeDC()
composite_obj_one.children

composite_obj_two=CompositeDC()
composite_obj_two.add(composite_obj_one)


print(composite_obj_one.parent)

print(composite_obj_two.children)
print(composite_obj_one.children)

print(composite_obj_two.parent)
# Out:
# CompositeDC(_parent=[], _children=[CompositeDC(_parent=..., _children=[])])
# [CompositeDC(_parent=CompositeDC(_parent=[], _children=[...]), _children=[])]
# []
# []

# %% [raw]
# okay so now it looks like we have some equivalent of the basic one.
#
# I will add the quicktype classes. it should give empty lists, I guess

# %%
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(CompositeDC):
    horizon_length: float
    interval_length: float
    

    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(CompositeDC):
    settings: Settings
  

    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent=optopy_input_from_dict(Optopy_inputs)

data_with_parent.settings.horizon_length

# print(data_with_parent.settings.parent)
print(data_with_parent.settings.children)
# print(data_with_parent.parent)
# print(data_with_parent.children)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-55592313a4de> in <module>
#       4
#       5 @dataclass
# ----> 6 class Settings(CompositeDC):
#       7     horizon_length: float
#       8     interval_length: float
#
# /usr/lib/python3.7/dataclasses.py in dataclass(_cls, init, repr, eq, order, unsafe_hash, frozen)
#     989
#     990     # We're called as @dataclass without parens.
# --> 991     return wrap(_cls)
#     992
#     993
#
# /usr/lib/python3.7/dataclasses.py in wrap(cls)
#     981
#     982     def wrap(cls):
# --> 983         return _process_class(cls, init, repr, eq, order, unsafe_hash, frozen)
#     984
#     985     # See if we're being called as @dataclass or @dataclass().
#
# /usr/lib/python3.7/dataclasses.py in _process_class(cls, init, repr, eq, order, unsafe_hash, frozen)
#     902                                     # if possible.
#     903                                     '__dataclass_self__' if 'self' in fields
# --> 904                                             else 'self',
#     905                           ))
#     906
#
# /usr/lib/python3.7/dataclasses.py in _init_fn(fields, frozen, has_post_init, self_name)
#     488                 seen_default = True
#     489             elif seen_default:
# --> 490                 raise TypeError(f'non-default argument {f.name!r} '
#     491                                 'follows default argument')
#     492
#
# TypeError: non-default argument 'horizon_length' follows default argument

# %% [raw]
# okay so now we get this bad error I was talking about. How to deal with it?
#
# so the summary of ideas,
# -maybe this dataclasses is not worth it after all ?!!
# - We can't really convert any of the @dataclasses to the standard ones since it would defeat the purpose.
# - We also need minimal changes to the quicktype classes.
# - The rule is if you have a default variable in the base class you can't have non-default (poitional) in the subclass.
# - So either we have to make sure to add a default value to all the quicktypes, or to remove the defaults from the base
# - finally one one thing that may work is using the __post_init__() method.
#
#
# So lets see how it works if we add some default to all, it is certainly not a good approach, but will it worrk?

# %%
_no_default = object()



    
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(CompositeDC):
    horizon_length: float  = _no_default
    interval_length: float = _no_default
        
     
    

    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        print(obj.get("horizon_length"))
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(CompositeDC):
    settings: Settings = _no_default
        
        
#     def __post_init__(self):
#         if self.settings is _no_default:
#             raise TypeError("__init__ missing  required arguments")

  

    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent=optopy_input_from_dict(Optopy_inputs)

data_with_parent.settings.horizon_length

# print(data_with_parent.settings.parent)
print(data_with_parent.settings.children)
# print(data_with_parent.parent)
# print(data_with_parent.children)
# Out:
# 24.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-6bc055784085> in <module>
#      50 data_with_parent=optopy_input_from_dict(Optopy_inputs)
#      51
# ---> 52 data_with_parent.settings.horizon_length
#      53
#      54 # print(data_with_parent.settings.parent)
#
# AttributeError: 'object' object has no attribute 'horizon_length'

# %%
Optopy_inputs
# Out:
# {'settings': {'horizon_length': 24.0, 'interval_length': 0.25}}

# %% [raw]
# okay so one problem here is that, by adding a default we don't get the actuall initilized value.

# %%
_no_default = object()



    
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(CompositeDC):
    horizon_length: float  = field(default_factory=float)
    interval_length: float = field(default_factory=float)
        
     
    

    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        print(obj.get("horizon_length"))
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(CompositeDC):
    settings: Settings = _no_default
        
        
#     def __post_init__(self):
#         if self.settings is _no_default:
#             raise TypeError("__init__ missing  required arguments")

  

    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent=optopy_input_from_dict(Optopy_inputs)

data_with_parent.settings.horizon_length

# print(data_with_parent.settings.parent)
print(data_with_parent.settings.children)
# print(data_with_parent.parent)
# Out:
# 24.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-e6abdab9724d> in <module>
#      50 data_with_parent=optopy_input_from_dict(Optopy_inputs)
#      51
# ---> 52 data_with_parent.settings.horizon_length
#      53
#      54 # print(data_with_parent.settings.parent)
#
# AttributeError: 'object' object has no attribute 'horizon_length'

# %%
_no_default = object()

def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(CompositeDC):
    horizon_length: float  = field(default_factory=float)
    interval_length: float = field(default_factory=float)
        
    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        print(obj.get("horizon_length"))
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(CompositeDC):
    settings: Settings = field(default_factory=Settings)
        
    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent2=optopy_input_from_dict(Optopy_inputs)

data_with_parent2.settings.horizon_length

print(data_with_parent2.settings.parent)
print(data_with_parent2.settings.children)
print(data_with_parent2.parent)
print(data_with_parent2.children)
# Out:
# 24.0
# []
# []
# Settings(_parent=24.0, _children=0.25, horizon_length=0.0, interval_length=0.0)
# []

# %%
so this _no_default thing does not work here, but a default factory seems to work.
Side Note Also this one below works(??)

# %%
_no_default = object()

def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(CompositeDC):
    horizon_length: float  = _no_default
    interval_length: float = _no_default
        
    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        print(obj.get("horizon_length"))
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(CompositeDC):
    settings: Settings = field(default_factory=Settings)
        
    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent2=optopy_input_from_dict(Optopy_inputs)

data_with_parent2.settings.horizon_length

print(data_with_parent2.settings.parent)
print(data_with_parent2.settings.children)
print(data_with_parent2.parent)
print(data_with_parent2.children)
# Out:
# 24.0
# []
# []
# Settings(_parent=24.0, _children=0.25, horizon_length=<object object at 0x7f1c4c325e30>, interval_length=<object object at 0x7f1c4c325e30>)
# []

# %% [raw]
# well looking closely actually this does not work either, since it has listed setting as the parent of OptopyInput.
# looks like the setting object is passed to the Base class of the Optopy_object which is a Composite and then passed to Component class, which initialize the
# parent  feature whihc was supposed to be an empty list built by defaul_factory.

# %% [raw]
# Okay so maybe we can fix this unintended initilializaion of Composite and Component classes by post_init

# %%
_no_default = object()

@dataclass
class ComponentDC(ABC):
    
    _parent: Component = _no_default
        
    def __post_init__(self):
        if self._parent == _no_default:
            print("looks like this works!")
            self._parent=None
        
    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass

@dataclass
class CompositeDC(ComponentDC):
    _children: List[Component] = _no_default 
    
    def __post_init__(self):
        
        if self._children == _no_default:
            print("looks like this works too!")
            self._children = []
            
    @property
    def children(self) -> List[Component]:
        return self._children

 
    def add(self, component: Component) -> None:
        self._children.append(component)
        component.parent = self

        
composite_obj_one= CompositeDC()
composite_obj_one.children

composite_obj_two=CompositeDC()
composite_obj_two.add(composite_obj_one)


print(composite_obj_one.parent)

print(composite_obj_two.children)
print(composite_obj_one.children)

print(composite_obj_two.parent)
# Out:
# looks like this works too!
# looks like this works too!
# CompositeDC(_parent=<object object at 0x7f1c4c325df0>, _children=[CompositeDC(_parent=..., _children=[])])
# [CompositeDC(_parent=CompositeDC(_parent=<object object at 0x7f1c4c325df0>, _children=[...]), _children=[])]
# []
# <object object at 0x7f1c4c325df0>

# %% [raw]
# okay so the post init looks like it works but it is more like the init method of regular classes.
# so we need super()__post_init__() for calling the parent.

# %%
_no_default = object()

@dataclass
class ComponentDC(ABC):
    
    _parent: Component = _no_default
        
    def __post_init__(self):
        if self._parent == _no_default:
            print("looks like this works!")
            self._parent=None

    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass

@dataclass
class CompositeDC(ComponentDC):
    _children: List[Component] = _no_default 
    
    def __post_init__(self):
        
        super().__post_init__()
        if self._children == _no_default:
            print("looks like this works too!")
            self._children = []
            
    @property
    def children(self) -> List[Component]:
        return self._children

 
    def add(self, component: Component) -> None:
        self._children.append(component)
        component.parent = self

        
composite_obj_one= CompositeDC()
composite_obj_one.children

composite_obj_two=CompositeDC()
composite_obj_two.add(composite_obj_one)


print(composite_obj_one.parent)

print(composite_obj_two.children)
print(composite_obj_one.children)

print(composite_obj_two.parent)
# Out:
# looks like this works!
# looks like this works too!
# looks like this works!
# looks like this works too!
# CompositeDC(_parent=None, _children=[CompositeDC(_parent=..., _children=[])])
# [CompositeDC(_parent=CompositeDC(_parent=None, _children=[...]), _children=[])]
# []
# None

# %%
_no_default = object()

def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(CompositeDC):
    horizon_length: float  = _no_default
    interval_length: float = _no_default
        
    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        print(obj.get("horizon_length"))
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(CompositeDC):
    settings: Settings = field(default_factory=Settings)
        
    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent2=optopy_input_from_dict(Optopy_inputs)

data_with_parent2.settings.horizon_length

print(data_with_parent2.settings.parent)
print(data_with_parent2.settings.children)
print(data_with_parent2.parent)
print(data_with_parent2.children)
# Out:
# 24.0
# <object object at 0x7f1c4c325a50>
# <object object at 0x7f1c4c325a50>
# Settings(_parent=24.0, _children=0.25, horizon_length=<object object at 0x7f1c4c3251b0>, interval_length=<object object at 0x7f1c4c3251b0>)
# <object object at 0x7f1c4c325a50>

# %% [raw]
# okay this did not work.  Clearly settings is still a component that can be passed as a parent to the Optopy_input class.
# alos looks like the post_init methods are not called.

# %%
_no_default = object()

@dataclass
class ComponentDC(ABC):
    
#     _parent: Component = _no_default
    def __post_init__(self):
        print("looks like this works for component!")
        self._parent=None

    @property
    def parent(self) -> Component:
        return self._parent

    @parent.setter
    def parent(self, parent: Component):
        self._parent = parent

    def add(self, component: Component) -> None:
        pass

@dataclass
class CompositeDC(ComponentDC):
#     _children: List[Component] = _no_default 
    
    def __post_init__(self):
        
        super().__post_init__()
#         if self._children == _no_default:
        print("looks like this works for composite too!")
        self._children = []
            
    @property
    def children(self) -> List[Component]:
        return self._children

 
    def add(self, component: Component) -> None:
        self._children.append(component)
        component.parent = self

        
composite_obj_one= CompositeDC()
composite_obj_one.children

composite_obj_two=CompositeDC()
composite_obj_two.add(composite_obj_one)


print(composite_obj_one.parent)

print(composite_obj_two.children)
print(composite_obj_one.children)

print(composite_obj_two.parent)
# Out:
# looks like this works for component!
# looks like this works for composite too!
# looks like this works for component!
# looks like this works for composite too!
# CompositeDC()
# [CompositeDC()]
# []
# None

# %%
_no_default = object()

def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(CompositeDC):
    horizon_length: float  = _no_default
    interval_length: float = _no_default
        
    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        print(obj.get("horizon_length"))
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(CompositeDC):
    settings: Settings = field(default_factory=Settings)
        
    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent2=optopy_input_from_dict(Optopy_inputs)

data_with_parent2.settings.horizon_length

print(data_with_parent2.settings.parent)
print(data_with_parent2.settings.children)
print(data_with_parent2.parent)
print(data_with_parent2.children)
# Out:
# 24.0
# looks like this works for component!
# looks like this works for composite too!
# looks like this works for component!
# looks like this works for composite too!
# None
# []
# None
# []

# %% [raw]
# okay so now we got what we wanted !!
# So maybe we can avoid adding the deafult_factory or _no_defalut all together, since we removed the default things in the base classses.
# This will look look the complete post init solution I was trying to come up with

# %%
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(CompositeDC):
    horizon_length: float  
    interval_length: float 
    
    def __post_init__(self):        
        super().__post_init__()
       
        
    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        print(obj.get("horizon_length"))
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)


@dataclass
class OptopyInput(CompositeDC):
    settings: Settings 
    
    def __post_init__(self):        
        super().__post_init__()
        
        
    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)


def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)


data_with_parent2=optopy_input_from_dict(Optopy_inputs)

data_with_parent2.settings.horizon_length

print(data_with_parent2.settings.parent)
print(data_with_parent2.settings.children)
print(data_with_parent2.parent)
print(data_with_parent2.children)
# Out:
# 24.0
# looks like this works for component!
# looks like this works for composite too!
# looks like this works for component!
# looks like this works for composite too!
# None
# []
# None
# []

# %% [raw]
# yes! finally it works! so I guess I could also add the children/parents here is a well.

# %%
def from_float(x: Any) -> float:
    assert isinstance(x, (float, int)) and not isinstance(x, bool)
    return float(x)

@dataclass
class Settings(CompositeDC):
    horizon_length: float  
    interval_length: float 
    
    def __post_init__(self):        
        super().__post_init__()
       
        
    @staticmethod
    def from_dict(obj: Any) -> 'Settings':
        assert isinstance(obj, dict)
        print(obj.get("horizon_length"))
        horizon_length = from_float(obj.get("horizon_length"))
        interval_length = from_float(obj.get("interval_length"))
        return Settings(horizon_length, interval_length)

@dataclass
class OptopyInput(CompositeDC):
    settings: Settings 
    
    def __post_init__(self):        
        super().__post_init__()
        self.add(self.settings)
               
    @staticmethod
    def from_dict(obj: Any) -> 'OptopyInput':
        assert isinstance(obj, dict)
        settings = Settings.from_dict(obj.get("settings"))
        
        return OptopyInput(settings)

def optopy_input_from_dict(s: Any) -> OptopyInput:
    return OptopyInput.from_dict(s)

data_with_parent2=optopy_input_from_dict(Optopy_inputs)
data_with_parent2.settings.horizon_length

print(data_with_parent2.settings.parent)
print(data_with_parent2.settings.children)
print(data_with_parent2.parent)
print(data_with_parent2.children)
# Out:
# 24.0
# looks like this works for component!
# looks like this works for composite too!
# looks like this works for component!
# looks like this works for composite too!
# OptopyInput(settings=Settings(horizon_length=24.0, interval_length=0.25))
# []
# None
# [Settings(horizon_length=24.0, interval_length=0.25)]
