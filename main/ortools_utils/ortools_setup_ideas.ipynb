# %% [markdown]
# ## How to import and setup ORtools:

# %% [markdown]
# So I want to know how to setup and install the ORtools in a container
#
# ORtools has a distribution for python already.
#
# I want to have the ORtools available as a service.
# so should I install it in python and place a grpc service in front of it?
# This would be the simplest way.
#
# Having ortools cpp distribution in front of the cpp grpc service is also the good way of doing this. but are there other ways?
#
# the cpp distribution has a protobuf interface. can we call it without grpc?
#
#
# Sending data as a message (ie memory copies) is significantly faster than writing it to disk.
#
#
#
# https://softwareengineering.stackexchange.com/questions/117552/how-to-have-two-different-programs-with-two-different-languages-interact

# %% [markdown]
# ## using stdin and stdout to connect two apps?

# %% [markdown]
# > Have you tested this in a real environment ever? Printing to console is usually much slower than writing to disk, it is not just leaving the characters in a buffer, but the buffer is limited, and the contents of that buffer need to be moved to the video card (a real text terminal) or drawn on the screen (a graphical terminal) with enough data, the intermediate buffer fills, and the writer process stalls waiting for the output to be drawn. Before making this type of strong statements on performance, actually measure, in a real environment with enough data you will see that yourself.
#
# > When you output something to a stream (such as cout), whatever you send is stored in a buffer before it is actually put there (flushed). It happens every now and then, and when the program's execution completes correctly. However, using flush or endl explicitly flushes it. This just ensures that things get printed when we want them to.
#
# > Writing to a file would be much faster. This is especially true since you are flushing the buffer after every line with endl.
#
# > On a side note, you could speed the printing significantly by doing repeating cout << "text!\n"; 5000 times, then flushing the buffer using flush().
#
# https://www.quora.com/Why-is-outputting-a-string-to-the-console-slower-than-writing-the-same-output-to-a-text-file

# %% [markdown]
# is this anything similar to the named pipe approach?

# %% [markdown]
# ## using ROS for message exchange?

# %% [markdown]
# origirnal question: is file writing to disk faster than passing message
#
# >Sending data as a message (ie memory copies) is significantly faster than writing it to disk.
#
# >Have a look at these latency numbers for a comparison of the speed of different operations, and remember that ROS message passing (network traffic) between different nodes on the same computer is actually just a memory copy, and never uses the network hardware.
#
# https://answers.ros.org/question/246692/what-is-more-efficient-writing-to-disk-or-message-passing-a-huge-amount-of-data-as-an-array-between-a-python-node-and-cpp-node/

# %% [markdown]
# ## custom RPCs

# %% [markdown]
# well I knew protobuf has RPC support independent of gRPC. So is there any advanatge trying to implement one?
# so I got this idea that maybe some of the stuff that grpc implement would not needed on the same machine? so maybe the protobuf RPC could be used directly.
# The protobuf examples does not povide any info in favor of this.

# %% [markdown]
# create a swig
#
#
#
# https://stackoverflow.com/questions/41849910/how-to-make-swig-interface-file-for-c-protobuf
#
#
# what is the swig? how it works?

# %% [markdown]
# ## good practices around grpc
#
# https://dzone.com/articles/the-modern-way-of-managing-apis-using-protobuf-and

# %% [markdown]
# ## grpc or Named pipes

# %% [markdown]
# When should I use Pipes or gRPC for interprocess communication (in C# .NET Core)?
#
# https://stackoverflow.com/questions/65186138/when-should-i-use-pipes-or-grpc-for-interprocess-communication-in-c-sharp-net
#
#
# seems that named pipes can be a bit faster, but generally grpc is prefered.
